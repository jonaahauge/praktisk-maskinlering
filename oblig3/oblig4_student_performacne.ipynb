# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from scikeras.wrappers import KerasClassifier

# %%
df = pd.read_csv(r"..\oblig3\student_performance.csv", delimiter=";")

# %%
targets = pd.Series(LabelEncoder().fit_transform(df['Target']))
features = df.drop('Target', axis=1)

# %%
f_train, f_test, t_train, t_test = train_test_split(features, targets, test_size=0.2)

# %%
scaler = MinMaxScaler()
scaler.fit(f_train)
f_train = scaler.transform(f_train)
f_test = scaler.transform(f_test)

# %%
def create_model(optimizer="adam", kernel_initializer='glorot_uniform'):
    model = Sequential()
    model.add(Input(shape=(36,)))
    model.add(Dense(100, activation='relu', kernel_initializer=kernel_initializer))
    model.add(Dense(50, activation='relu', kernel_initializer=kernel_initializer))
    model.add(Dense(20, activation='relu', kernel_initializer=kernel_initializer))
    model.add(Dense(1, activation='sigmoid', kernel_initializer=kernel_initializer))
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
kears_estimator = KerasClassifier(model=create_model, verbose=1)

# %%
param_grid = {
    #'batch_size': [10, 20, 40],
    #'epochs': [10, 20, 40],
    #'optimizer': ['SGD', 'Adam', 'RMSprop'],
    'model__kernel_initializer': ['glorot_uniform', 'normal', 'uniform'],     
    'model__optimizer': ['adam', 'sgd']
    #'model__kernel_initializer': ['glorot_uniform', 'he_normal']
}

# %%
from sklearn.model_selection import GridSearchCV


grid = GridSearchCV(estimator=kears_estimator, verbose=1, return_train_score=True, cv=5, param_grid=param_grid)

# %%
grid_result = grid.fit(f_train, t_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1975 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1713 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1844 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1756 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2246 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2172 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1713 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1752 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1883 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1794 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2130 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1727 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1816 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1741 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1769 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1809 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1759 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1770 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1738 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1734 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1851 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1713 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1763 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1727 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1741 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1780 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1734 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1766 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1745 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1737 - loss: 0.0000e+00
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# c:\Users\hallo\Documents\GitHub\praktisk-maskinlering\.venv\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1786 - loss: 0.0000e+00
