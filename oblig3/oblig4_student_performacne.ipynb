# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import GridSearchCV, StratifiedKFold, KFold
from sklearn.metrics import make_scorer, get_scorer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from scikeras.wrappers import KerasClassifier

# %%
df = pd.read_csv(r"..\oblig3\student_performance.csv", delimiter=";")

# %%
encoder = OneHotEncoder(sparse_output=False)

targets = encoder.fit_transform(df[['Target']])
features = pd.DataFrame(StandardScaler().fit_transform(df.drop('Target', axis=1)), columns=df.drop('Target', axis=1).columns)

# %%
df_targets = pd.DataFrame(targets, columns=encoder.get_feature_names_out(['Target']))

# %%
print(targets.shape)
# Out:
# (4424, 3)

# %%
from numpy import average


global_random_state = 15

scoring = {
    'accuracy': get_scorer('accuracy'),
    'precision': make_scorer(precision_score, average='macro', zero_division=1.0),
    'recall': make_scorer(recall_score, average='macro', zero_division=1.0),
    'f1': make_scorer(f1_score, average='macro'),
    'roc_auc': make_scorer(roc_auc_score, multi_class='ovr', average='macro', response_method='predict')   
}

def evaluate(estimator, X, y):
    scores = {}
    for (name,scorer) in scoring.items():
        scores[name] = scorer(estimator, X, y) 
    return scores

def train(features, targets, estimator, params, scoring=scoring, refit='f1', random_state=global_random_state, outer_splits=5, inner_splits=4):

    outer_cv = KFold(n_splits=outer_splits, shuffle=True, random_state=global_random_state)
    inner_cv = KFold(n_splits=inner_splits, shuffle=True, random_state=global_random_state)

    scores_train = []
    scores_test = []
    estimators = []
    cv_results = []

    # Loop through all test folds
    for (train_index, test_index) in outer_cv.split(features, targets):
        
        grid = GridSearchCV(
            estimator,
            params, 
            scoring=scoring, 
            refit=refit,
            error_score='raise', 
            cv=inner_cv)
        grid.fit(features.iloc[train_index], targets[train_index])        
        
        evaluation_train = evaluate(grid, features.iloc[train_index], targets[train_index])
        evaluation_test = evaluate(grid, features.iloc[test_index], targets[test_index])
        
        scores_train.append(evaluation_train)
        scores_test.append(evaluation_test)
        
        estimators.append(grid.best_estimator_)
        cv_results.append(pd.DataFrame(grid.cv_results_))
        print("*")

    return estimators, pd.DataFrame(scores_train), pd.DataFrame(scores_test), pd.concat(cv_results, names=['test_split'], keys=range(outer_splits))

def print_estimators(estimators):
    for estimatior in estimators:
        print(estimatior)

def create_model(optimizer="adam", kernel_initializer='glorot_uniform'):
    model = Sequential()
    model.add(Input(shape=(36,)))
    model.add(Dense(100, activation='relu', kernel_initializer=kernel_initializer))
    model.add(Dense(50, activation='relu', kernel_initializer=kernel_initializer))
    model.add(Dense(20, activation='relu', kernel_initializer=kernel_initializer))
    model.add(Dense(3, activation='softmax', kernel_initializer=kernel_initializer))
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
param_grid = {
    #'batch_size': [10, 20, 40],
    #'epochs': [10, 20, 40],
    #'optimizer': ['SGD', 'Adam', 'RMSprop'],
    #'model__kernel_initializer': ['glorot_uniform', 'normal', 'uniform'],     
    'model__optimizer': ['adam', 'sgd']
    #'model__kernel_initializer': ['glorot_uniform', 'he_normal']
}

kearas_model = KerasClassifier(model=create_model, verbose=1)

# %%
kearas_estimators, kearas_scores_train, kearas_scores_test, kearas_cv_results = train(features, targets, kearas_model, param_grid)
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6978 - loss: 0.7501
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6797 - loss: 0.7905
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6673 - loss: 0.8307
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6667 - loss: 0.8013
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5629 - loss: 0.9937
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5674 - loss: 0.9811
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5953 - loss: 0.9602
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5985 - loss: 0.9477
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6996 - loss: 0.7392
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# *
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6726 - loss: 0.8027
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6138 - loss: 0.8812
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6658 - loss: 0.8331
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6851 - loss: 0.7707
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4906 - loss: 1.0445
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5821 - loss: 0.9669
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4872 - loss: 1.0638
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6215 - loss: 0.9628
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6691 - loss: 0.7887
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# *
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6552 - loss: 0.8019
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6797 - loss: 0.7544
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6503 - loss: 0.8256
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6810 - loss: 0.8030
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5712 - loss: 0.9546
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4898 - loss: 1.0324
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5682 - loss: 0.9959
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4787 - loss: 1.0656
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7070 - loss: 0.7233
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# *
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6797 - loss: 0.7700
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6665 - loss: 0.8089
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6843 - loss: 0.7735
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6508 - loss: 0.8410
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5328 - loss: 1.0018
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5369 - loss: 1.0250
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5723 - loss: 0.9896
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5013 - loss: 1.0362
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6994 - loss: 0.7434
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# *
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6561 - loss: 0.8010
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7153 - loss: 0.7420
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6377 - loss: 0.8499
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6927 - loss: 0.7600
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5944 - loss: 0.9870
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5782 - loss: 0.9628
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5616 - loss: 0.9928
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5544 - loss: 0.9922
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6785 - loss: 0.7830
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# *

# %%
kearas_scores_test
# Out:
#    accuracy  precision    recall        f1   roc_auc
# 0  0.714124   0.616647  0.605863  0.603684  0.722351
# 1  0.751412   0.697612  0.650812  0.654811  0.753754
# 2  0.770621   0.695828  0.663537  0.672716  0.767223
# 3  0.758192   0.714996  0.627238  0.624395  0.741209
# 4  0.730769   0.668174  0.623109  0.595804  0.735007

# %%
grid = GridSearchCV(estimator=kearas_model, verbose=1, scoring=scoring, return_train_score=True, cv=5, param_grid=param_grid, refit='f1', error_score='raise')

# %%
grid_result = grid.fit(features, df_targets)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6982 - loss: 0.7332
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6844 - loss: 0.7560
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7030 - loss: 0.7413
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6287 - loss: 0.8463
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6901 - loss: 0.7599
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5770 - loss: 0.9928
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6262 - loss: 0.9092
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5519 - loss: 0.9991
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5680 - loss: 0.9679
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4893 - loss: 1.0329
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6944 - loss: 0.7404

# %%
test = pd.DataFrame(grid_result.cv_results_)
evaluate(grid, features, targets)
# Out:
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step
# {'accuracy': 0.7646925858951176,
#  'precision': 0.7119948046370185,
#  'recall': 0.6721228687872497,
#  'f1': 0.6834109523379018,
#  'roc_auc': 0.7692931968168505}
